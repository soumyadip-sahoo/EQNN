# %% [markdown]
# Indrouces noise due to Y gate for quantum to classical map ... explain

# %%
# !pip3 install --upgrade pip
# !pip3 install tensorflow==2.15.0
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.2 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.3
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow==2.15.0)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.15.0)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.14.1)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.73.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 57.3 MB/s  0:00:06
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 91.6 MB/s  0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.8 MB/s  0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 221.0 MB/s  0:00:00
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.0 MB/s  0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Downloading wrapt-1.14.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (77 kB)
# Installing collected packages: wrapt, tensorflow-estimator, protobuf, numpy, keras, ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.18.0
#     Uninstalling tensorflow-2.18.0:
#       Successfully uninstalled tensorflow-2.18.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [tensorflow]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# jax 0.5.2 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.2.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tensorstore 0.1.74 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.15.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 numpy-1.26.4 protobuf-4.25.8 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.2

# %%
# !pip3 install -U tensorflow-quantum
# Out:
# Collecting tensorflow-quantum
#   Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting cirq-core==1.3.0 (from tensorflow-quantum)
#   Downloading cirq_core-1.3.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cirq-google==1.3.0 (from tensorflow-quantum)
#   Downloading cirq_google-1.3.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting sympy==1.12 (from tensorflow-quantum)
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting duet~=0.2.8 (from cirq-core==1.3.0->tensorflow-quantum)
#   Downloading duet-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (3.10.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (3.5)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (2.2.2)
# Requirement already satisfied: sortedcontainers~=2.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (2.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (1.15.3)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (4.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum) (4.67.1)
# Requirement already satisfied: google-api-core>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (2.25.1)
# Requirement already satisfied: proto-plus>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum) (1.26.1)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum) (4.25.8)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy==1.12->tensorflow-quantum) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (1.70.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (2.38.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (0.6.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum) (1.71.2)
# Collecting protobuf>=3.15.0 (from cirq-google==1.3.0->tensorflow-quantum)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum) (2025.2)
# Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.1 MB/s  0:00:01
# Downloading cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 48.5 MB/s  0:00:00
# Downloading cirq_google-1.3.0-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.8/598.8 kB 3.3 MB/s  0:00:00
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 57.6 MB/s  0:00:00
# Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: sympy, protobuf, duet, cirq-core, cirq-google, tensorflow-quantum
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [tensorflow-quantum]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.5 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.15.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.12 which is incompatible.
# Successfully installed cirq-core-1.3.0 cirq-google-1.3.0 duet-0.2.9 protobuf-5.29.5 sympy-1.12 tensorflow-quantum-0.7.3

# %%
# !pip3 install -U tfq-nightly
# Out:
# ERROR: Could not find a version that satisfies the requirement tfq-nightly (from versions: none)
# ERROR: No matching distribution found for tfq-nightly

# %%
# 2 CLASS MNIST 500 TRAINING SAMPLE ; NOISE = 0.02
#
# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)

# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.02):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.02)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.00)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_mnist_500_noise_0.02.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_mnist_500_noise_0.02.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2115, 28, 28)
# Test labels shape: (2115,)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 7/7 [==============================] - ETA: 0s - loss: 0.7000 - accuracy: 0.5138
# Epoch 1: val_loss improved from inf to 0.86362, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 48s 7s/step - loss: 0.7000 - accuracy: 0.5138 - val_loss: 0.8636 - val_accuracy: 0.0700 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.5950
# Epoch 2: val_loss did not improve from 0.86362
# 7/7 [==============================] - 47s 7s/step - loss: 0.6555 - accuracy: 0.5950 - val_loss: 0.9653 - val_accuracy: 0.0150 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6342 - accuracy: 0.6075
# Epoch 3: val_loss did not improve from 0.86362
# 7/7 [==============================] - 46s 7s/step - loss: 0.6342 - accuracy: 0.6075 - val_loss: 0.9202 - val_accuracy: 0.0200 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5966 - accuracy: 0.6300
# Epoch 4: val_loss improved from 0.86362 to 0.76054, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.5966 - accuracy: 0.6300 - val_loss: 0.7605 - val_accuracy: 0.2450 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7525
# Epoch 5: val_loss improved from 0.76054 to 0.62344, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.5550 - accuracy: 0.7525 - val_loss: 0.6234 - val_accuracy: 0.8450 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.8737
# Epoch 6: val_loss improved from 0.62344 to 0.58442, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.5133 - accuracy: 0.8737 - val_loss: 0.5844 - val_accuracy: 0.9050 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.8763
# Epoch 7: val_loss did not improve from 0.58442
# 7/7 [==============================] - 47s 7s/step - loss: 0.4739 - accuracy: 0.8763 - val_loss: 0.5996 - val_accuracy: 0.8500 - lr: 0.0095
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4377 - accuracy: 0.8938
# Epoch 8: val_loss improved from 0.58442 to 0.53455, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.4377 - accuracy: 0.8938 - val_loss: 0.5345 - val_accuracy: 0.9850 - lr: 0.0094
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.9137
# Epoch 9: val_loss improved from 0.53455 to 0.48336, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.4058 - accuracy: 0.9137 - val_loss: 0.4834 - val_accuracy: 0.9850 - lr: 0.0094
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.9112
# Epoch 10: val_loss improved from 0.48336 to 0.45307, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.3786 - accuracy: 0.9112 - val_loss: 0.4531 - val_accuracy: 0.9850 - lr: 0.0093
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.9112
# Epoch 11: val_loss improved from 0.45307 to 0.42195, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.3541 - accuracy: 0.9112 - val_loss: 0.4220 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.9150
# Epoch 12: val_loss improved from 0.42195 to 0.40728, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.3329 - accuracy: 0.9150 - val_loss: 0.4073 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.9125
# Epoch 13: val_loss improved from 0.40728 to 0.35042, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.3130 - accuracy: 0.9125 - val_loss: 0.3504 - val_accuracy: 0.9850 - lr: 0.0091
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9100
# Epoch 14: val_loss did not improve from 0.35042
# 7/7 [==============================] - 45s 6s/step - loss: 0.2966 - accuracy: 0.9100 - val_loss: 0.3734 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.9162
# Epoch 15: val_loss improved from 0.35042 to 0.34964, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2831 - accuracy: 0.9162 - val_loss: 0.3496 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9162
# Epoch 16: val_loss improved from 0.34964 to 0.32185, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.2708 - accuracy: 0.9162 - val_loss: 0.3218 - val_accuracy: 0.9850 - lr: 0.0089
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9150
# Epoch 17: val_loss improved from 0.32185 to 0.31378, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.2614 - accuracy: 0.9150 - val_loss: 0.3138 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9175
# Epoch 18: val_loss did not improve from 0.31378
# 7/7 [==============================] - 46s 6s/step - loss: 0.2526 - accuracy: 0.9175 - val_loss: 0.3320 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9175
# Epoch 19: val_loss improved from 0.31378 to 0.30082, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2450 - accuracy: 0.9175 - val_loss: 0.3008 - val_accuracy: 0.9850 - lr: 0.0087
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9187
# Epoch 20: val_loss did not improve from 0.30082
# 7/7 [==============================] - 46s 7s/step - loss: 0.2384 - accuracy: 0.9187 - val_loss: 0.3112 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9250
# Epoch 21: val_loss did not improve from 0.30082
# 7/7 [==============================] - 45s 6s/step - loss: 0.2336 - accuracy: 0.9250 - val_loss: 0.3182 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9250
# Epoch 22: val_loss improved from 0.30082 to 0.28221, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2281 - accuracy: 0.9250 - val_loss: 0.2822 - val_accuracy: 0.9850 - lr: 0.0085
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9225
# Epoch 23: val_loss did not improve from 0.28221
# 7/7 [==============================] - 47s 7s/step - loss: 0.2252 - accuracy: 0.9225 - val_loss: 0.2831 - val_accuracy: 0.9850 - lr: 0.0084
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9237
# Epoch 24: val_loss did not improve from 0.28221
# 7/7 [==============================] - 46s 7s/step - loss: 0.2208 - accuracy: 0.9237 - val_loss: 0.2895 - val_accuracy: 0.9850 - lr: 0.0084
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9225
# Epoch 25: val_loss improved from 0.28221 to 0.27429, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2184 - accuracy: 0.9225 - val_loss: 0.2743 - val_accuracy: 0.9850 - lr: 0.0083
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9325
# Epoch 26: val_loss did not improve from 0.27429
# 7/7 [==============================] - 45s 6s/step - loss: 0.2157 - accuracy: 0.9325 - val_loss: 0.3117 - val_accuracy: 0.9850 - lr: 0.0083
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9300
# Epoch 27: val_loss improved from 0.27429 to 0.26872, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.2135 - accuracy: 0.9300 - val_loss: 0.2687 - val_accuracy: 0.9850 - lr: 0.0082
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9300
# Epoch 28: val_loss did not improve from 0.26872
# 7/7 [==============================] - 45s 6s/step - loss: 0.2102 - accuracy: 0.9300 - val_loss: 0.2850 - val_accuracy: 0.9850 - lr: 0.0081
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9325
# Epoch 29: val_loss did not improve from 0.26872
# 7/7 [==============================] - 44s 6s/step - loss: 0.2084 - accuracy: 0.9325 - val_loss: 0.2724 - val_accuracy: 0.9850 - lr: 0.0081
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9312
# Epoch 30: val_loss improved from 0.26872 to 0.26623, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2065 - accuracy: 0.9312 - val_loss: 0.2662 - val_accuracy: 0.9850 - lr: 0.0080
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9325
# Epoch 31: val_loss did not improve from 0.26623
# 7/7 [==============================] - 47s 7s/step - loss: 0.2057 - accuracy: 0.9325 - val_loss: 0.2733 - val_accuracy: 0.9850 - lr: 0.0080
# Epoch 32/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9287
# Epoch 32: val_loss improved from 0.26623 to 0.24084, saving model to best_model_mnist_500.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2038 - accuracy: 0.9287 - val_loss: 0.2408 - val_accuracy: 0.9850 - lr: 0.0079
# Epoch 33/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9287
# Epoch 33: val_loss did not improve from 0.24084
# 7/7 [==============================] - 45s 6s/step - loss: 0.2032 - accuracy: 0.9287 - val_loss: 0.2700 - val_accuracy: 0.9850 - lr: 0.0078
# Epoch 34/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9362
# Epoch 34: val_loss did not improve from 0.24084
# 7/7 [==============================] - 46s 6s/step - loss: 0.2005 - accuracy: 0.9362 - val_loss: 0.2626 - val_accuracy: 0.9850 - lr: 0.0078
# Epoch 35/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9337
# Epoch 35: val_loss did not improve from 0.24084
# 7/7 [==============================] - 45s 6s/step - loss: 0.1994 - accuracy: 0.9337 - val_loss: 0.2538 - val_accuracy: 0.9850 - lr: 0.0077
# 67/67 [==============================] - 17s 250ms/step - loss: 0.2334 - accuracy: 0.9234
# Test accuracy: 0.9234
# 67/67 [==============================] - 17s 252ms/step
# Precision: 0.9259
# Recall: 0.9234
# F1 Score: 0.9230

# %%
# FASHION MNIST 2 CLASSES 500 TAINING SAMPLES , NOISE =0.02
#
# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)

# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.02):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.02)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.00)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_f_mnist_500_noise_0.02.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_f_mnist_500_noise_0.02.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2000, 28, 28)
# Test labels shape: (2000,)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 7/7 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.6162
# Epoch 1: val_loss improved from inf to 0.89396, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.6713 - accuracy: 0.6162 - val_loss: 0.8940 - val_accuracy: 0.0100 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.6200
# Epoch 2: val_loss did not improve from 0.89396
# 7/7 [==============================] - 48s 7s/step - loss: 0.6312 - accuracy: 0.6200 - val_loss: 0.8947 - val_accuracy: 0.0150 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5981 - accuracy: 0.6500
# Epoch 3: val_loss improved from 0.89396 to 0.82827, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.5981 - accuracy: 0.6500 - val_loss: 0.8283 - val_accuracy: 0.2750 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 0.7350
# Epoch 4: val_loss improved from 0.82827 to 0.79288, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 48s 7s/step - loss: 0.5657 - accuracy: 0.7350 - val_loss: 0.7929 - val_accuracy: 0.4500 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.7650
# Epoch 5: val_loss improved from 0.79288 to 0.75408, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.5347 - accuracy: 0.7650 - val_loss: 0.7541 - val_accuracy: 0.5600 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7725
# Epoch 6: val_loss did not improve from 0.75408
# 7/7 [==============================] - 46s 7s/step - loss: 0.5032 - accuracy: 0.7725 - val_loss: 0.7994 - val_accuracy: 0.4900 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.7900
# Epoch 7: val_loss did not improve from 0.75408
# 7/7 [==============================] - 47s 7s/step - loss: 0.4785 - accuracy: 0.7900 - val_loss: 0.7573 - val_accuracy: 0.5950 - lr: 0.0095
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.8037
# Epoch 8: val_loss improved from 0.75408 to 0.71545, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.4562 - accuracy: 0.8037 - val_loss: 0.7154 - val_accuracy: 0.6550 - lr: 0.0094
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.7987
# Epoch 9: val_loss did not improve from 0.71545
# 7/7 [==============================] - 46s 6s/step - loss: 0.4402 - accuracy: 0.7987 - val_loss: 0.7478 - val_accuracy: 0.6150 - lr: 0.0094
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4291 - accuracy: 0.8075
# Epoch 10: val_loss improved from 0.71545 to 0.64806, saving model to best_model_f_mnist_500_noise_0.02.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.4291 - accuracy: 0.8075 - val_loss: 0.6481 - val_accuracy: 0.7450 - lr: 0.0093
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4218 - accuracy: 0.8037
# Epoch 11: val_loss did not improve from 0.64806
# 7/7 [==============================] - 45s 6s/step - loss: 0.4218 - accuracy: 0.8037 - val_loss: 0.7528 - val_accuracy: 0.6100 - lr: 0.0092
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.8075
# Epoch 12: val_loss did not improve from 0.64806
# 7/7 [==============================] - 47s 7s/step - loss: 0.4170 - accuracy: 0.8075 - val_loss: 0.7243 - val_accuracy: 0.6700 - lr: 0.0092
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8075
# Epoch 13: val_loss did not improve from 0.64806
# 7/7 [==============================] - 46s 6s/step - loss: 0.4137 - accuracy: 0.8075 - val_loss: 0.6564 - val_accuracy: 0.7450 - lr: 0.0091
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4927 - accuracy: 0.7565
# Test accuracy: 0.7565
# 63/63 [==============================] - 16s 246ms/step
# Precision: 0.7566
# Recall: 0.7565
# F1 Score: 0.7565

# %%
# FASHION MNIST 2 CLASSES 500 TRAINING SAMPLES ; NOISE = 0.03 [ run ]
#
# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)



# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.03):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.03)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.00)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_f_mnist_500_noise_0.03.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_f_mnist_500_noise_0.03.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2000, 28, 28)
# Test labels shape: (2000,)
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5934 - accuracy: 0.6837
# Epoch 1: val_loss improved from inf to 0.82750, saving model to best_model_f_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 120s 16s/step - loss: 0.5934 - accuracy: 0.6837 - val_loss: 0.8275 - val_accuracy: 0.4100 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5530 - accuracy: 0.7212
# Epoch 2: val_loss improved from 0.82750 to 0.79002, saving model to best_model_f_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 118s 17s/step - loss: 0.5530 - accuracy: 0.7212 - val_loss: 0.7900 - val_accuracy: 0.4800 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.7425
# Epoch 3: val_loss improved from 0.79002 to 0.75278, saving model to best_model_f_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 118s 17s/step - loss: 0.5249 - accuracy: 0.7425 - val_loss: 0.7528 - val_accuracy: 0.5050 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.7550
# Epoch 4: val_loss improved from 0.75278 to 0.66442, saving model to best_model_f_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 123s 17s/step - loss: 0.4997 - accuracy: 0.7550 - val_loss: 0.6644 - val_accuracy: 0.6150 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.7688
# Epoch 5: val_loss did not improve from 0.66442
# 7/7 [==============================] - 125s 18s/step - loss: 0.4798 - accuracy: 0.7688 - val_loss: 0.6768 - val_accuracy: 0.5900 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.7700
# Epoch 6: val_loss did not improve from 0.66442
# 7/7 [==============================] - 124s 18s/step - loss: 0.4625 - accuracy: 0.7700 - val_loss: 0.6679 - val_accuracy: 0.6150 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.7725
# Epoch 7: val_loss did not improve from 0.66442
# 7/7 [==============================] - 124s 18s/step - loss: 0.4480 - accuracy: 0.7725 - val_loss: 0.6909 - val_accuracy: 0.6100 - lr: 0.0095
# 63/63 [==============================] - 45s 708ms/step - loss: 0.5293 - accuracy: 0.7290
# Test accuracy: 0.7290
# 63/63 [==============================] - 46s 734ms/step
# Precision: 0.7409
# Recall: 0.7290
# F1 Score: 0.7256

# %%
# MNIST 2 CLASSES 500 TRAINING SAMPLE ; NOISE = 0.03
#

# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)

# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.03):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.03)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.00)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_mnist_500_noise_0.03.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_mnist_500_noise_0.03.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2115, 28, 28)
# Test labels shape: (2115,)
# Exception ignored in: <function _xla_gc_callback at 0x79bbc57f0f40>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 7/7 [==============================] - ETA: 0s - loss: 0.6708 - accuracy: 0.6037
# Epoch 1: val_loss improved from inf to 0.89787, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.6708 - accuracy: 0.6037 - val_loss: 0.8979 - val_accuracy: 0.0000e+00 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.6012
# Epoch 2: val_loss improved from 0.89787 to 0.80885, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 49s 7s/step - loss: 0.6405 - accuracy: 0.6012 - val_loss: 0.8089 - val_accuracy: 0.0000e+00 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.6187
# Epoch 3: val_loss did not improve from 0.80885
# 7/7 [==============================] - 54s 8s/step - loss: 0.6038 - accuracy: 0.6187 - val_loss: 0.8364 - val_accuracy: 0.0000e+00 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5649 - accuracy: 0.6212
# Epoch 4: val_loss improved from 0.80885 to 0.78583, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.5649 - accuracy: 0.6212 - val_loss: 0.7858 - val_accuracy: 0.0000e+00 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5240 - accuracy: 0.7400
# Epoch 5: val_loss improved from 0.78583 to 0.63845, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.5240 - accuracy: 0.7400 - val_loss: 0.6385 - val_accuracy: 0.8800 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.8725
# Epoch 6: val_loss improved from 0.63845 to 0.62134, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.4857 - accuracy: 0.8725 - val_loss: 0.6213 - val_accuracy: 0.8750 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4503 - accuracy: 0.8850
# Epoch 7: val_loss improved from 0.62134 to 0.59105, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.4503 - accuracy: 0.8850 - val_loss: 0.5910 - val_accuracy: 0.9200 - lr: 0.0095
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4200 - accuracy: 0.8913
# Epoch 8: val_loss improved from 0.59105 to 0.58444, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.4200 - accuracy: 0.8913 - val_loss: 0.5844 - val_accuracy: 0.9550 - lr: 0.0094
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.9162
# Epoch 9: val_loss improved from 0.58444 to 0.47494, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.3903 - accuracy: 0.9162 - val_loss: 0.4749 - val_accuracy: 0.9850 - lr: 0.0094
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.9125
# Epoch 10: val_loss improved from 0.47494 to 0.43681, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.3654 - accuracy: 0.9125 - val_loss: 0.4368 - val_accuracy: 0.9850 - lr: 0.0093
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.9175
# Epoch 11: val_loss did not improve from 0.43681
# 7/7 [==============================] - 45s 6s/step - loss: 0.3424 - accuracy: 0.9175 - val_loss: 0.4511 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.9125
# Epoch 12: val_loss improved from 0.43681 to 0.34304, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.3255 - accuracy: 0.9125 - val_loss: 0.3430 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3047 - accuracy: 0.9150
# Epoch 13: val_loss did not improve from 0.34304
# 7/7 [==============================] - 46s 6s/step - loss: 0.3047 - accuracy: 0.9150 - val_loss: 0.4019 - val_accuracy: 0.9850 - lr: 0.0091
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.9187
# Epoch 14: val_loss did not improve from 0.34304
# 7/7 [==============================] - 46s 7s/step - loss: 0.2898 - accuracy: 0.9187 - val_loss: 0.3842 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9162
# Epoch 15: val_loss improved from 0.34304 to 0.30886, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2779 - accuracy: 0.9162 - val_loss: 0.3089 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9137
# Epoch 16: val_loss did not improve from 0.30886
# 7/7 [==============================] - 47s 7s/step - loss: 0.2700 - accuracy: 0.9137 - val_loss: 0.3379 - val_accuracy: 0.9850 - lr: 0.0089
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9200
# Epoch 17: val_loss did not improve from 0.30886
# 7/7 [==============================] - 45s 6s/step - loss: 0.2623 - accuracy: 0.9200 - val_loss: 0.3617 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.9162
# Epoch 18: val_loss improved from 0.30886 to 0.30332, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.2559 - accuracy: 0.9162 - val_loss: 0.3033 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9175
# Epoch 19: val_loss did not improve from 0.30332
# 7/7 [==============================] - 45s 6s/step - loss: 0.2492 - accuracy: 0.9175 - val_loss: 0.3336 - val_accuracy: 0.9850 - lr: 0.0087
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9250
# Epoch 20: val_loss did not improve from 0.30332
# 7/7 [==============================] - 47s 7s/step - loss: 0.2454 - accuracy: 0.9250 - val_loss: 0.3507 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9212
# Epoch 21: val_loss improved from 0.30332 to 0.27993, saving model to best_model_mnist_500_noise_0.03.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2402 - accuracy: 0.9212 - val_loss: 0.2799 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9162
# Epoch 22: val_loss did not improve from 0.27993
# 7/7 [==============================] - 45s 6s/step - loss: 0.2379 - accuracy: 0.9162 - val_loss: 0.2879 - val_accuracy: 0.9850 - lr: 0.0085
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9225
# Epoch 23: val_loss did not improve from 0.27993
# 7/7 [==============================] - 46s 7s/step - loss: 0.2331 - accuracy: 0.9225 - val_loss: 0.3257 - val_accuracy: 0.9850 - lr: 0.0084
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9262
# Epoch 24: val_loss did not improve from 0.27993
# 7/7 [==============================] - 45s 6s/step - loss: 0.2305 - accuracy: 0.9262 - val_loss: 0.2875 - val_accuracy: 0.9850 - lr: 0.0084
# 67/67 [==============================] - 17s 254ms/step - loss: 0.2641 - accuracy: 0.9187
# Test accuracy: 0.9187
# 67/67 [==============================] - 17s 257ms/step
# Precision: 0.9226
# Recall: 0.9187
# F1 Score: 0.9182

# %%
# MNIST 2 CLASSES 500 TRINING SAMPLE ; NOISE 0.04 [ DON'T TAKE IT --GIVING HIGH RESULT ]
#
# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)

# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.04):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.04)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.00)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_mnist_500_noise_0.04.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_mnist_500_noise_0.04.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2115, 28, 28)
# Test labels shape: (2115,)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 7/7 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.6012
# Epoch 1: val_loss improved from inf to 0.90665, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.6385 - accuracy: 0.6012 - val_loss: 0.9067 - val_accuracy: 0.0000e+00 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5887 - accuracy: 0.6212
# Epoch 2: val_loss improved from 0.90665 to 0.77991, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.5887 - accuracy: 0.6212 - val_loss: 0.7799 - val_accuracy: 0.0450 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7663
# Epoch 3: val_loss improved from 0.77991 to 0.63119, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.5392 - accuracy: 0.7663 - val_loss: 0.6312 - val_accuracy: 0.9600 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.9075
# Epoch 4: val_loss improved from 0.63119 to 0.60758, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.4827 - accuracy: 0.9075 - val_loss: 0.6076 - val_accuracy: 0.9650 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.9225
# Epoch 5: val_loss improved from 0.60758 to 0.53494, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.4265 - accuracy: 0.9225 - val_loss: 0.5349 - val_accuracy: 0.9850 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.9075
# Epoch 6: val_loss improved from 0.53494 to 0.41477, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.3759 - accuracy: 0.9075 - val_loss: 0.4148 - val_accuracy: 0.9850 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3395 - accuracy: 0.8975
# Epoch 7: val_loss improved from 0.41477 to 0.37094, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.3395 - accuracy: 0.8975 - val_loss: 0.3709 - val_accuracy: 0.9850 - lr: 0.0095
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.9087
# Epoch 8: val_loss did not improve from 0.37094
# 7/7 [==============================] - 46s 7s/step - loss: 0.3081 - accuracy: 0.9087 - val_loss: 0.4086 - val_accuracy: 0.9850 - lr: 0.0094
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.9137
# Epoch 9: val_loss improved from 0.37094 to 0.32052, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2859 - accuracy: 0.9137 - val_loss: 0.3205 - val_accuracy: 0.9850 - lr: 0.0094
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.9100
# Epoch 10: val_loss improved from 0.32052 to 0.30571, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.2684 - accuracy: 0.9100 - val_loss: 0.3057 - val_accuracy: 0.9850 - lr: 0.0093
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2554 - accuracy: 0.9125
# Epoch 11: val_loss did not improve from 0.30571
# 7/7 [==============================] - 45s 6s/step - loss: 0.2554 - accuracy: 0.9125 - val_loss: 0.3176 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9137
# Epoch 12: val_loss improved from 0.30571 to 0.30384, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2452 - accuracy: 0.9137 - val_loss: 0.3038 - val_accuracy: 0.9850 - lr: 0.0092
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9200
# Epoch 13: val_loss improved from 0.30384 to 0.27519, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.2382 - accuracy: 0.9200 - val_loss: 0.2752 - val_accuracy: 0.9850 - lr: 0.0091
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9175
# Epoch 14: val_loss improved from 0.27519 to 0.26602, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.2315 - accuracy: 0.9175 - val_loss: 0.2660 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.9225
# Epoch 15: val_loss did not improve from 0.26602
# 7/7 [==============================] - 46s 6s/step - loss: 0.2264 - accuracy: 0.9225 - val_loss: 0.3070 - val_accuracy: 0.9850 - lr: 0.0090
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9250
# Epoch 16: val_loss improved from 0.26602 to 0.26286, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2215 - accuracy: 0.9250 - val_loss: 0.2629 - val_accuracy: 0.9850 - lr: 0.0089
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9237
# Epoch 17: val_loss did not improve from 0.26286
# 7/7 [==============================] - 46s 6s/step - loss: 0.2180 - accuracy: 0.9237 - val_loss: 0.2671 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9237
# Epoch 18: val_loss improved from 0.26286 to 0.26266, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.2149 - accuracy: 0.9237 - val_loss: 0.2627 - val_accuracy: 0.9850 - lr: 0.0088
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9237
# Epoch 19: val_loss improved from 0.26266 to 0.25451, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 6s/step - loss: 0.2122 - accuracy: 0.9237 - val_loss: 0.2545 - val_accuracy: 0.9850 - lr: 0.0087
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.9262
# Epoch 20: val_loss did not improve from 0.25451
# 7/7 [==============================] - 45s 6s/step - loss: 0.2099 - accuracy: 0.9262 - val_loss: 0.2762 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9275
# Epoch 21: val_loss did not improve from 0.25451
# 7/7 [==============================] - 47s 7s/step - loss: 0.2076 - accuracy: 0.9275 - val_loss: 0.2559 - val_accuracy: 0.9850 - lr: 0.0086
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9237
# Epoch 22: val_loss improved from 0.25451 to 0.24412, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 45s 6s/step - loss: 0.2070 - accuracy: 0.9237 - val_loss: 0.2441 - val_accuracy: 0.9850 - lr: 0.0085
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9275
# Epoch 23: val_loss did not improve from 0.24412
# 7/7 [==============================] - 47s 7s/step - loss: 0.2043 - accuracy: 0.9275 - val_loss: 0.2795 - val_accuracy: 0.9850 - lr: 0.0084
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9287
# Epoch 24: val_loss did not improve from 0.24412
# 7/7 [==============================] - 46s 7s/step - loss: 0.2037 - accuracy: 0.9287 - val_loss: 0.2568 - val_accuracy: 0.9850 - lr: 0.0084
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9275
# Epoch 25: val_loss improved from 0.24412 to 0.23923, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 46s 7s/step - loss: 0.2022 - accuracy: 0.9275 - val_loss: 0.2392 - val_accuracy: 0.9850 - lr: 0.0083
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9275
# Epoch 26: val_loss did not improve from 0.23923
# 7/7 [==============================] - 45s 6s/step - loss: 0.2020 - accuracy: 0.9275 - val_loss: 0.2695 - val_accuracy: 0.9850 - lr: 0.0083
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9312
# Epoch 27: val_loss did not improve from 0.23923
# 7/7 [==============================] - 47s 7s/step - loss: 0.2006 - accuracy: 0.9312 - val_loss: 0.2658 - val_accuracy: 0.9850 - lr: 0.0082
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9287
# Epoch 28: val_loss improved from 0.23923 to 0.23841, saving model to best_model_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 47s 7s/step - loss: 0.1996 - accuracy: 0.9287 - val_loss: 0.2384 - val_accuracy: 0.9850 - lr: 0.0081
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9287
# Epoch 29: val_loss did not improve from 0.23841
# 7/7 [==============================] - 46s 7s/step - loss: 0.1984 - accuracy: 0.9287 - val_loss: 0.2666 - val_accuracy: 0.9850 - lr: 0.0081
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9350
# Epoch 30: val_loss did not improve from 0.23841
# 7/7 [==============================] - 46s 7s/step - loss: 0.1998 - accuracy: 0.9350 - val_loss: 0.2897 - val_accuracy: 0.9800 - lr: 0.0080
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9362
# Epoch 31: val_loss did not improve from 0.23841
# 7/7 [==============================] - 45s 6s/step - loss: 0.1971 - accuracy: 0.9362 - val_loss: 0.2431 - val_accuracy: 0.9850 - lr: 0.0080
# 67/67 [==============================] - 17s 247ms/step - loss: 0.2282 - accuracy: 0.9314
# Test accuracy: 0.9314
# 67/67 [==============================] - 18s 263ms/step
# Precision: 0.9328
# Recall: 0.9314
# F1 Score: 0.9312

# %%
# FASHION MNIST 2 CLASSES 500 TAINING SAMPLES , NOISE =0.04 [ run ]
#
# =============================================================
# Imports
# =============================================================
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# =============================================================
# Load and preprocess dataset
# =============================================================
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

selected_classes = [0, 1]  # Digits 0 and 1
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Limit number of training samples per class
class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

x_train = np.concatenate(x_train_limited)
y_train = np.concatenate(y_train_limited)

print("Training set shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test set shape:", x_test.shape)
print("Test labels shape:", y_test.shape)

# Resize images to 4x4 grid for 16 qubits
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)

# =============================================================
# Quantum Circuit Definitions
# =============================================================

# Create qubits and parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers}')

# Define parameterized variational circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit





# Create example parameterized circuit
example_circuit = create_quantum_circuit(qubits, params, layers)

# =============================================================
# Noisy data encoding (adds Gaussian phase/amplitude noise)
# =============================================================
def create_quantum_data(images, noise_std=0.04):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            noisy_pixel = pixel + np.random.normal(0, noise_std)
            noisy_pixel = np.clip(noisy_pixel, 0.0, 1.0)
            circuit.append(cirq.rx(np.pi * noisy_pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

# Convert datasets to noisy quantum circuits
x_train_circuits = create_quantum_data(x_train, noise_std=0.04)
x_test_circuits  = create_quantum_data(x_test, noise_std=0.0)

# =============================================================
# Model Definition
# =============================================================
def create_model():
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Learning rate and callbacks
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=3, restore_best_weights=True
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_f_mnist_500_noise_0.04.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# =============================================================
# Compile and Train
# =============================================================
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[model_checkpoint, reduce_lr, early_stopping],
    verbose=1
)

model.load_weights("best_model_f_mnist_500_noise_0.04.h5")

# =============================================================
# Evaluation
# =============================================================
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# =============================================================
# Visualization
# =============================================================
def plot_history(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# =============================================================
# Metrics
# =============================================================
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Training set shape: (1000, 28, 28)
# Training labels shape: (1000,)
# Test set shape: (2000, 28, 28)
# Test labels shape: (2000,)
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6060 - accuracy: 0.6700
# Epoch 1: val_loss improved from inf to 0.92435, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 130s 18s/step - loss: 0.6060 - accuracy: 0.6700 - val_loss: 0.9243 - val_accuracy: 0.3550 - lr: 0.0099
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5696 - accuracy: 0.6775
# Epoch 2: val_loss improved from 0.92435 to 0.91992, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 124s 17s/step - loss: 0.5696 - accuracy: 0.6775 - val_loss: 0.9199 - val_accuracy: 0.4350 - lr: 0.0099
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5437 - accuracy: 0.7287
# Epoch 3: val_loss improved from 0.91992 to 0.75734, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 118s 17s/step - loss: 0.5437 - accuracy: 0.7287 - val_loss: 0.7573 - val_accuracy: 0.5900 - lr: 0.0098
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.7425
# Epoch 4: val_loss improved from 0.75734 to 0.75064, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 122s 17s/step - loss: 0.5217 - accuracy: 0.7425 - val_loss: 0.7506 - val_accuracy: 0.5850 - lr: 0.0097
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5008 - accuracy: 0.7550
# Epoch 5: val_loss did not improve from 0.75064
# 7/7 [==============================] - 118s 17s/step - loss: 0.5008 - accuracy: 0.7550 - val_loss: 0.7917 - val_accuracy: 0.5100 - lr: 0.0096
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7600
# Epoch 6: val_loss improved from 0.75064 to 0.74596, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 119s 17s/step - loss: 0.4867 - accuracy: 0.7600 - val_loss: 0.7460 - val_accuracy: 0.5700 - lr: 0.0096
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.7688
# Epoch 7: val_loss improved from 0.74596 to 0.60648, saving model to best_model_f_mnist_500_noise_0.04.h5
# 7/7 [==============================] - 119s 17s/step - loss: 0.4726 - accuracy: 0.7688 - val_loss: 0.6065 - val_accuracy: 0.7250 - lr: 0.0095
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.7788
# Epoch 8: val_loss did not improve from 0.60648
# 7/7 [==============================] - 122s 17s/step - loss: 0.4603 - accuracy: 0.7788 - val_loss: 0.7047 - val_accuracy: 0.6150 - lr: 0.0094
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.7837
# Epoch 9: val_loss did not improve from 0.60648
# 7/7 [==============================] - 120s 17s/step - loss: 0.4483 - accuracy: 0.7837 - val_loss: 0.7461 - val_accuracy: 0.5700 - lr: 0.0094
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.7775
# Epoch 10: val_loss did not improve from 0.60648
# 7/7 [==============================] - 117s 16s/step - loss: 0.4424 - accuracy: 0.7775 - val_loss: 0.6672 - val_accuracy: 0.6700 - lr: 0.0093
# 63/63 [==============================] - 43s 691ms/step - loss: 0.5141 - accuracy: 0.7385
# Test accuracy: 0.7385
# 63/63 [==============================] - 43s 673ms/step
# Precision: 0.7386
# Recall: 0.7385
# F1 Score: 0.7385
